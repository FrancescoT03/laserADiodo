# %% [markdown]
# # Diodo Laser
#
# Abbiamo efffettuato il primo ciclo di misure di Potenza vs Intensità a 23 gradi, con delle misure sia in salita (in corrente) che in discesa
#
# ## Freddo : 12 gradi
#
# ## Caldo : 44 gradi
# (Verso la metà delle misure la temperatura è scesa a 43)

# %% [markdown]
# # Fasci gaussiani
#
#  * Abbiamo allineato il rivelatore al fascio del laser. Prima verticalmente cercando un massimo e poi nel piano del tavolo.
# * Abbiamo ruotato il laser attorno a un asse passante per il centro del cerchio di fissaggio fino ad osservare un minimo dell'intensità attraverso un polaroid. In tal modo abbiamo allineato il piano della giunzione in modo perpendicolare
# * Abbiamo misurato l'intnesità ruotando il laser con il goniometro.
# * Abbiamo ruotato di 90° il laser per osservare l'altra dimensione (questo ha portato uno spostamento nella posizione del picco)

# %%
# Lunghezza d'onda

Abbiamo impostato il laser con una corrrenti di alimentazione di 63.3 mA
A 31 gradi abbiamo alzato la corrente a 69.1 mA

A causa della variazione della soglia del laser con la temperatura non abbiamo potuto mantenere una potenza costante (in realtà una corrente).
L'abbiamo modificata per non scendere sotto la metà dell'intensità massima misurabile dal fotocromatore
