# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

I, P = np.loadtxt(r'C:\Users\F.Pampanoni\OneDrive - University of Pisa\UNIVERSITÁ\MAGISTRALE\MATTER PHYSICS LAB\laser_diode\data\I_P_12C.txt', unpack=True)
plt.plot(I, P, '.', color='blue')

plt.show()
